# %%
import pandas as pd
import numpy as np
from keras.callbacks import EarlyStopping
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder
import tensorflow as tf

# %%
trainData = pd.read_csv('Glass_Quality_Participants_Data/Train.csv')

# %%
# Number of columns = 16  Train
# Number of rows = 1358   Train

# Number of columns = 15  Test
# Number of rows = 583   Test

# %%
# Columns
# Index(['grade_A_Component_1', 'grade_A_Component_2', 'max_luminosity',
#        'thickness', 'xmin', 'xmax', 'ymin', 'ymax', 'pixel_area', 'log_area',
#        'x_component_1', 'x_component_2', 'x_component_3', 'x_component_4',
#        'x_component_5', 'class'],
#       dtype='object')

# %%
features = trainData.iloc[:,:-1]
labels = trainData.iloc[:,-1]

# %%
labels = labels.values.reshape(-1,1)
# labels = np.array([i[0]-1 for i in labels]).reshape(-1,1)
labels.shape
# Out:
# (1358, 1)

# %%
def ohencoder(labels):
    return np.array([[0,1] if i[0] == 2 else [1,0] for i in labels])

ohencoded_labels = ohencoder(labels)

# %%
ohencoded_labels.shape
# Out:
# (1358, 2)

# %%
features = features.astype('float')

# %%
features.info()

# %%
# x and grade_A are categorical variables
# No missing values

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

features.hist(column=["xmax", "xmin","ymin","ymax",])

# %%
features.hist(column=["max_luminosity","pixel_area","log_area"])#,,,

# %%
features.corr()

# %%
# pixel_area and log_area
# xmin and xmax
# ymin and ymax
# The above pairs have a very high degree of positive correlation

# %%
features = features.drop(columns=['pixel_area', 'xmax','ymax'])

# %%
features.shape
# Out:
# (1358, 12)

# %%
features.corr()

# %%
np_features = features.to_numpy()
np_labels = ohencoded_labels

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(np_features, np_labels, test_size=0.33, random_state=42)

# %%
X_train.shape, X_test.shape
# Out:
# ((909, 12), (449, 12))

# %%
from keras import models, layers, optimizers
model = models.Sequential()
model.add(layers.Dense(10, activation = 'relu', input_dim = 12))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(5, activation = 'relu'))
model.add(layers.Dense(8, activation = 'relu'))
model.add(layers.Dense(2, activation = 'softmax'))


model.compile(optimizer = optimizers.adam(lr = 1e-3),
              loss = 'categorical_crossentropy',
              metrics = [tf.keras.metrics.CategoricalAccuracy()]
             )

# %%
my_callbacks = [
    EarlyStopping(patience=3),
    
    
]

# %%
history = model.fit(X_train, y_train, epochs = 100, batch_size = 20, callbacks=my_callbacks, validation_data=[X_test, y_test]
)
# Out:
# Train on 909 samples, validate on 449 samples
# Epoch 1/100
# 909/909 [==============================] - 0s 341us/step - loss: 24626.8173 - categorical_accuracy: 0.4673 - val_loss: 12033.4953 - val_categorical_accuracy: 0.4524
# Epoch 2/100
# 909/909 [==============================] - 0s 98us/step - loss: 9828.9614 - categorical_accuracy: 0.4390 - val_loss: 3893.5807 - val_categorical_accuracy: 0.4327
# Epoch 3/100
# 909/909 [==============================] - 0s 92us/step - loss: 2802.3481 - categorical_accuracy: 0.4278 - val_loss: 127.2206 - val_categorical_accuracy: 0.4232
# Epoch 4/100
# 909/909 [==============================] - 0s 93us/step - loss: 533.1580 - categorical_accuracy: 0.4362 - val_loss: 2.7408 - val_categorical_accuracy: 0.4567
# Epoch 5/100
# 909/909 [==============================] - 0s 91us/step - loss: 194.9772 - categorical_accuracy: 0.4724 - val_loss: 11.9970 - val_categorical_accuracy: 0.4880
# Epoch 6/100
# 909/909 [==============================] - 0s 91us/step - loss: 163.5658 - categorical_accuracy: 0.4981 - val_loss: 0.6795 - val_categorical_accuracy: 0.5086
# Epoch 7/100
# 909/909 [==============================] - 0s 91us/step - loss: 81.3880 - categorical_accuracy: 0.5163 - val_loss: 2.9848 - val_categorical_accuracy: 0.5242
# Epoch 8/100
# 909/909 [==============================] - 0s 89us/step - loss: 202.0297 - categorical_accuracy: 0.5292 - val_loss: 8.3899 - val_categorical_accuracy: 0.5340
# Epoch 9/100
# 909/909 [==============================] - 0s 92us/step - loss: 54.2339 - categorical_accuracy: 0.5383 - val_loss: 2.2535 - val_categorical_accuracy: 0.5412

# %%
ypreds = model.predict(X_test)

# %%
ypreds
# Out:
# array([[9.99669194e-01, 3.30797979e-04],
#        [9.99985099e-01, 1.48545796e-05],
#        [8.30250263e-01, 1.69749677e-01],
#        [7.15274870e-01, 2.84725159e-01],
#        [9.92788255e-01, 7.21175736e-03],
#        [8.67933810e-01, 1.32066160e-01],
#        [9.17746007e-01, 8.22539404e-02],
#        [9.94825363e-01, 5.17468294e-03],
#        [7.46185184e-01, 2.53814757e-01],
#        [1.00000000e+00, 1.86938509e-09],
#        [9.92830098e-01, 7.16992747e-03],
#        [8.89096260e-01, 1.10903732e-01],
#        [9.99111712e-01, 8.88230454e-04],
#        [1.00000000e+00, 1.01637975e-22],
#        [9.99702871e-01, 2.97115126e-04],
#        [9.91546214e-01, 8.45380872e-03],
#        [9.99981403e-01, 1.86317484e-05],
#        [6.30201399e-01, 3.69798571e-01],
#        [7.47569859e-01, 2.52430111e-01],
#        [9.99222159e-01, 7.77846552e-04],
#        [7.71499336e-01, 2.28500605e-01],
#        [9.12280023e-01, 8.77200142e-02],
#        [9.99987721e-01, 1.22190750e-05],
#        [8.02594244e-01, 1.97405785e-01],
#        [9.36110020e-01, 6.38899878e-02],
#        [6.37595117e-01, 3.62404913e-01],
#        [1.00000000e+00, 9.41964196e-09],
#        [9.99996543e-01, 3.44657883e-06],
#        [1.00000000e+00, 6.55033272e-09],
#        [9.99978900e-01, 2.11537590e-05],
#        [1.00000000e+00, 3.58281760e-08],
#        [9.88668263e-01, 1.13317538e-02],
#        [8.89336824e-01, 1.10663235e-01],
#        [9.99998093e-01, 1.91831305e-06],
#        [9.98907685e-01, 1.09231903e-03],
#        [9.31742489e-01, 6.82574734e-02],
#        [6.51243925e-01, 3.48756015e-01],
#        [9.96227264e-01, 3.77274770e-03],
#        [9.99852300e-01, 1.47680388e-04],
#        [9.56390500e-01, 4.36095297e-02],
#        [9.98530626e-01, 1.46932108e-03],
#        [9.99829292e-01, 1.70640429e-04],
#        [6.51382625e-01, 3.48617405e-01],
#        [7.35451639e-01, 2.64548302e-01],
#        [9.73316967e-01, 2.66830903e-02],
#        [9.99832273e-01, 1.67667589e-04],
#        [9.88679230e-01, 1.13208182e-02],
#        [9.98402178e-01, 1.59784546e-03],
#        [7.81372368e-01, 2.18627691e-01],
#        [9.93076086e-01, 6.92395400e-03],
#        [9.99724090e-01, 2.75867904e-04],
#        [9.57277775e-01, 4.27221954e-02],
#        [9.00223136e-01, 9.97767970e-02],
#        [9.94759500e-01, 5.24044922e-03],
#        [1.00000000e+00, 5.57928703e-11],
#        [9.99998927e-01, 1.06770290e-06],
#        [8.72781694e-01, 1.27218261e-01],
#        [9.96942580e-01, 3.05745797e-03],
#        [9.64522421e-01, 3.54775004e-02],
#        [6.00364089e-01, 3.99635911e-01],
#        [9.99789774e-01, 2.10293336e-04],
#        [8.71146381e-01, 1.28853649e-01],
#        [9.60435390e-01, 3.95645536e-02],
#        [9.99890208e-01, 1.09750901e-04],
#        [6.60966158e-01, 3.39033872e-01],
#        [8.27514768e-01, 1.72485247e-01]], dtype=float32)

# %%
samplesubmission = pd.DataFrame(ypreds, columns = ['1','2'])

# %%
samplesubmission
# Out:
#             1         2
# 0    0.999669  0.000331
# 1    0.999985  0.000015
# 2    0.830250  0.169750
# 3    0.715275  0.284725
# 4    0.992788  0.007212
# ..        ...       ...
# 444  0.871146  0.128854
# 445  0.960435  0.039565
# 446  0.999890  0.000110
# 447  0.660966  0.339034
# 448  0.827515  0.172485
#
# [449 rows x 2 columns]

# %%
def ontocat(arr):
    return np.array([0 if i[0]==1 else 1 for i in arr])

catypreds = ontocat(ypreds)
catytest = ontocat(y_test)

# %% [markdown]
# # Validation

# %%
testData = pd.read_csv('Glass_Quality_Participants_Data/Test.csv')

# %%
testfeatures = testData.drop(columns=['pixel_area', 'xmax','ymax'])

# %%
testfeatures = testfeatures.astype('float')

# %%
np_testfeatures = testfeatures.to_numpy()

# %%
testpreds = model.predict(np_testfeatures)

# %%
testpreds_df = pd.DataFrame(testpreds, columns=['1','2'])

# %%
# !pip3 install openpyxl
# Out:
# Collecting openpyxl
#   Downloading https://files.pythonhosted.org/packages/95/8c/83563c60489954e5b80f9e2596b93a68e1ac4e4a730deb1aae632066d704/openpyxl-3.0.3.tar.gz (172kB)
#     100% |████████████████████████████████| 174kB 548kB/s ta 0:00:01
# Collecting jdcal (from openpyxl)
#   Downloading https://files.pythonhosted.org/packages/f0/da/572cbc0bc582390480bbd7c4e93d14dc46079778ed915b505dc494b37c57/jdcal-1.4.1-py2.py3-none-any.whl
# Collecting et_xmlfile (from openpyxl)
#   Downloading https://files.pythonhosted.org/packages/22/28/a99c42aea746e18382ad9fb36f64c1c1f04216f41797f2f0fa567da11388/et_xmlfile-1.0.1.tar.gz
# Building wheels for collected packages: openpyxl, et-xmlfile
#   Running setup.py bdist_wheel for openpyxl ... done
#   Stored in directory: /home/shouvik/.cache/pip/wheels/b5/85/ca/e768ac132e57e75e645a151f8badac71cc0089e7225dddf76b
#   Running setup.py bdist_wheel for et-xmlfile ... done
#   Stored in directory: /home/shouvik/.cache/pip/wheels/2a/77/35/0da0965a057698121fc7d8c5a7a9955cdbfb3cc4e2423cad39
# Successfully built openpyxl et-xmlfile
# Installing collected packages: jdcal, et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.0.1 jdcal-1.4.1 openpyxl-3.0.3

# %%
testpreds_df.to_excel('submission.xlsx', index=False)
